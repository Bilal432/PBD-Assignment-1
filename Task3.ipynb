# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
zarrar = pd.read_csv('jsrt_metadata.csv')
zarrar.replace('?',np.nan,inplace=True)
y=zarrar['diagnosis'].isnull().sum()
y
# Out:
# 93

# %%
y=zarrar['diagnosis'].value_counts().idxmax()
y
# Out:
# 'lung cancer'

# %%
zarrar['diagnosis'].replace(np.nan,y,inplace=True)

# %%
s=zarrar[['diagnosis', 'gender']]
s
# Out:
#               diagnosis  gender
# 0           lung cancer    Male
# 1    pulmonary hematoma  Female
# 2           lung cancer  Female
# 3     Inflammatory mass  Female
# 4           lung cancer  Female
# ..                  ...     ...
# 242         lung cancer    Male
# 243         lung cancer  Female
# 244         lung cancer    Male
# 245         lung cancer  Female
# 246         lung cancer    Male
#
# [247 rows x 2 columns]

# %%
zarrar[(zarrar['diagnosis']=='lung cancer(adenocarcinoma)') & (zarrar['gender']=='Female')]
# Out:
#          study_id  subtlety  size age  gender       x       y      state  \
# 16   JPCLN017.png       4.0  30.0  70  Female   533.0   758.0  malignant
# 37   JPCLN038.png       4.0  20.0  68  Female   848.0   303.0  malignant
# 50   JPCLN051.png       3.0  25.0  64  Female   524.0   586.0  malignant
# 51   JPCLN052.png       3.0  30.0  76  Female   836.0   881.0  malignant
# 53   JPCLN054.png       3.0  26.0  58  Female   533.0   746.0  malignant
# 58   JPCLN059.png       3.0  27.0  70  Female   565.0   377.0  malignant
# 61   JPCLN062.png       3.0  15.0  41  Female  1618.0   934.0  malignant
# 81   JPCLN082.png       3.0  20.0  46  Female   459.0   950.0  malignant
# 98   JPCLN099.png       3.0  10.0  63  Female   524.0   504.0  malignant
# 104  JPCLN105.png       2.0  30.0  63  Female   590.0  1471.0  malignant
# 113  JPCLN114.png       2.0  20.0  76  Female   447.0   762.0  malignant
# 127  JPCLN128.png       2.0  20.0  62  Female   614.0  1376.0  malignant
# ...

# %%
y=zarrar['diagnosis'].value_counts()
y
# Out:
# lung cancer                                       149
# lung cancer(adenocarcinoma)                        23
# tuberculoma                                        14
# granuloma                                           8
# lung cancer(bronchioloalveolar cell carcinoma)      7
# unknown                                             4
# metastasis of colon cancer                          4
# inflammatory mass                                   4
# pulmonary tuberculosis                              3
# lung abscess                                        2
# Cryptococcosis                                      2
# lung cancer(squamous cell carcinoma)                2
# Inflammatory mass                                   2
# pulmonary hematoma                                  2
# susp. inflammatory mass                             2
# hamartoma                                           2
# sclerosing hemangioma                               2
# ...

# %%
zarrar[(zarrar['diagnosis']=='granuloma') & (zarrar['gender']=='Female')]
# Out:
#         study_id  subtlety  size age  gender       x      y   state  \
# 7   JPCLN008.png       5.0  10.0  44  Female   508.0  938.0  benign
# 99  JPCLN100.png       3.0   9.0  71  Female  1606.0  315.0  benign
#
#         position  diagnosis
# 7   r.lower lobe  granuloma
# 99  l.upper lobe  granuloma

# %%
labels = ['Male Lung_cancer','Female Lung_cander']
sizes = [75,74]
fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%')
ax.axis('equal')  # Equal aspect ratio ensures the pie chart is circular.
#ax.set_title('Number_of_Patients')
plt.show()

# %%
labels = ['Male Lung_cancer_Adenocarcinoma','Female Lung_cander_Adenocarcinoma']
sizes = [8,15]
fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%')
ax.axis('equal')  # Equal aspect ratio ensures the pie chart is circular.
#ax.set_title('Number_of_Patients')
plt.show()

# %%
labels = ['Male tuberculoma','Female tuberculoma']
sizes = [9,5]
fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%')
ax.axis('equal')  # Equal aspect ratio ensures the pie chart is circular.
#ax.set_title('Number_of_Patients')
plt.show()

# %%
labels = ['Male_Granuloma','Female_Granuloma']
sizes = [6,2]
fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%')
ax.axis('equal')  # Equal aspect ratio ensures the pie chart is circular.
#ax.set_title('Number_of_Patients')
plt.show()
